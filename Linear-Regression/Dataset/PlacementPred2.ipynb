# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('placement.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X=df['cgpa'].values

# %%
Y=df['package'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
model=SGDRegressor(eta0=0.001, max_iter=1000, random_state=2)

# %%
X_train=X_train.reshape(-1,1)

# %%
model.fit(X_train,y_train)
# Out:
# SGDRegressor(eta0=0.001, random_state=2)

# %%
X_test=X_test.reshape(-1,1)

# %%
model.predict(X_test)
# Out:
# array([3.68601319, 3.08067707, 2.54307087, 2.68699694, 1.98853219,
#        2.08166082, 2.30601617, 2.9579166 , 3.58865144, 2.96214972,
#        3.8384055 , 3.39816105, 2.98754844, 2.55577023, 3.15264011,
#        3.3642961 , 2.20865441, 3.19497131, 2.99178156, 3.32619802,
#        2.67429758, 3.13570763, 2.90288605, 3.10184267, 3.52938776,
#        2.91135229, 3.38546169, 3.27116746, 3.70717879, 2.22135377,
#        3.50398905, 3.16957259, 3.57171896, 2.84785549, 2.84362237,
#        3.21613691, 3.41086041, 2.71662878, 2.75049374, 2.79282493])

# %%
mse=mean_squared_error(y_test,model.predict(X_test))

# %%
mse
# Out:
# 0.16086654798314828

# %%
sns.scatterplot(df,x='cgpa',y='package')
plt.plot(X_test,model.predict(X_test),color='red')
plt.title('Linear Regression Plot')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.show()

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
model.predict([[6.89]])
# Out:
# array([2.97061596])
