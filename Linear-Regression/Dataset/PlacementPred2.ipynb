# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('placement.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X=df['cgpa'].values

# %%
Y=df['package'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
model=SGDRegressor(eta0=0.01, max_iter=1000,random_state=2, alpha=0.01,tol=1e-3)

# %%
X_train=X_train.reshape(-1,1)

# %%
model.fit(X_train,y_train)
# Out:
# SGDRegressor(alpha=0.01, random_state=2)

# %%
X_test=X_test.reshape(-1,1)

# %%
model.predict(X_test)
# Out:
# array([3.72777952, 3.10574797, 2.55331435, 2.70120997, 1.98348126,
#        2.07917842, 2.30972158, 2.97960171, 3.62773248, 2.98395158,
#        3.88437487, 3.43198829, 3.01005081, 2.56636397, 3.17969577,
#        3.39718932, 2.20967455, 3.22319448, 3.01440068, 3.35804048,
#        2.68816035, 3.16229629, 2.92305339, 3.12749732, 3.56683429,
#        2.93175313, 3.41893868, 3.30149216, 3.74952887, 2.22272416,
#        3.54073506, 3.19709526, 3.610333  , 2.86650506, 2.86215519,
#        3.24494384, 3.4450379 , 2.73165906, 2.76645803, 2.80995674])

# %%
mse=mean_squared_error(y_test,model.predict(X_test))

# %%
mse
# Out:
# 0.15868973315628754

# %%
sns.scatterplot(df,x='cgpa',y='package')
plt.plot(X_test,model.predict(X_test),color='red')
plt.title('Linear Regression Plot')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.show()

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
model.predict([[6.89]])
# Out:
# array([2.99265132])

# %%
model.coef_
# Out:
# array([0.4349871])
